# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Sun Nov 13 20:18:23 2022
"""
# Out:
# '\nCreated on Sun Nov 13 20:18:23 2022\n'

# %%
# %autosave 5
# Out:
# Autosaving every 5 seconds

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('../Exercise Files/Datasets/insurance.csv')

# %%
df.head(15)
# Out:
#     age     sex     bmi  children smoker     region      charges
# 0    19  female  27.900         0    yes  southwest  16884.92400
# 1    18    male  33.770         1     no  southeast   1725.55230
# 2    28    male  33.000         3     no  southeast   4449.46200
# 3    33    male  22.705         0     no  northwest  21984.47061
# 4    32    male  28.880         0     no  northwest   3866.85520
# 5    31  female  25.740         0     no  southeast   3756.62160
# 6    46  female  33.440         1     no  southeast   8240.58960
# 7    37  female  27.740         3     no  northwest   7281.50560
# 8    37    male  29.830         2     no  northeast   6406.41070
# 9    60  female  25.840         0     no  northwest  28923.13692
# 10   25    male  26.220         0     no  northeast   2721.32080
# 11   62  female  26.290         0    yes  southeast  27808.72510
# 12   23    male  34.400         0     no  southwest   1826.84300
# ...

# %%
count_na = df.isnull().sum()

# %%
count_na
# Out:
# age         0
# sex         0
# bmi         5
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
count_na[count_na > 0]
# Out:
# bmi    5
# dtype: int64

# %%
df['bmi'].fillna(df['bmi'].mean(), inplace=True)

# %%
count_na = df.isnull().sum()

# %%
count_na
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
count_na[count_na > 0]
# Out:
# Series([], dtype: int64)

# %%
df2 = pd.read_csv('../Exercise Files/Datasets/insurance.csv')
df2.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df2.drop('bmi', axis=1, inplace=True)

# %%
count_na = df2.isnull().sum()

# %%
count_na
# Out:
# age         0
# sex         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
count_na[count_na > 0]
# Out:
# Series([], dtype: int64)

# %%
df3 = pd.read_csv('../Exercise Files/Datasets/insurance.csv')
df3.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df3.dropna(inplace=True)
df3.reset_index(drop=True, inplace=True)

# %%
count_na = df3.isnull().sum()
count_na
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
count_na[count_na > 0]
# Out:
# Series([], dtype: int64)

# %%
df4 = pd.read_csv('../Exercise Files/Datasets/insurance.csv')
df4.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df4.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         5
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
imputer = SimpleImputer(strategy='mean')
imputer.fit(df4['bmi'].values.reshape(-1, 1))
df4['bmi'] = imputer.transform(
    df4['bmi'].values.reshape(-1, 1))

# %%
df4.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
df5 = pd.read_csv('../Exercise Files/Datasets/insurance.csv')
df5.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df5.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         5
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
df5['bmi'].fillna(df5['bmi'].mean(), inplace=True)

# %%
df5.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
figure, ax = plt.subplots(4, 2, figsize=(12, 24))

sns.distplot(df5['charges'], ax=ax[0,0])
sns.distplot(df5['age'], ax=ax[0,1])
sns.distplot(df5['bmi'],ax= ax[1,0])
sns.distplot(df5['children'], ax=ax[1,1])

sns.countplot(df5['sex'], ax=ax[2,0])
sns.countplot(df5['smoker'], ax=ax[2,1])
sns.countplot(df5['region'], ax=ax[3,0])

sns.pairplot(df5)

sns.lmplot(x='age', y='charges', hue='smoker',
           data=df5, palette='muted', height=7)
plt.show(sns);
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...
