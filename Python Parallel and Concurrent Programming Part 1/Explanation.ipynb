# %%
# %autosave 5
# Out:
# Autosaving every 5 seconds

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import Image

# %matplotlib inline

# %%
meaning = {
    'SISD': 'Single Instruction Single Data',
    'MISD': 'Multiple Intruction Sinle Data',
    'SIMD': 'Single Instruction Multiple Data',
    'MIMD': 'Multiple Instruction Multiple Data'
}

# %%
df = pd.DataFrame({
    'Single': ['SISD', 'MISD'],
    'Multiple': ['SIMD', 'MIMD']
}, index=['Sigle', 'Multiple'])
df
# Out:
#          Single Multiple
# Sigle      SISD     SIMD
# Multiple   MISD     MIMD

# %%
df.applymap(lambda val: meaning[val])
# Out:
#                                   Single                            Multiple
# Sigle     Single Instruction Single Data    Single Instruction Multiple Data
# Multiple  Multiple Intruction Sinle Data  Multiple Instruction Multiple Data

# %%
Image('Flynn Taxonomy.PNG')

# %%
Image('Parallel Executation.PNG')

# %%
df = pd.DataFrame({
    'model': ['Single Program, Multiple Data',
              'Multiple Program, Multiple Data'],
    'abbr': ['SPMD', 'MPMD']
})
df
# Out:
#                              model  abbr
# 0    Single Program, Multiple Data  SPMD
# 1  Multiple Program, Multiple Data  MPMD

# %% [markdown]
# <b>Shared Memory</b>: all processors access the same memory with global addres space.<p></p>
# Can be:
# <li>Uniform memory access (UMA)</li>
# <li>No-uniform memory access (NUMA)

# %%
! pip install folium
